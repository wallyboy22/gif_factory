# %% [markdown]
# # 🖼️ IPAM GIF Factory — Hub Dashboard
# Interface inspirada no Streamlit para monitoramento e gestão do Hub de GIFs no Google Cloud Storage.

# %% [markdown]
# ### ⚙️ 1. Setup do Ambiente
# Esta célula configura os caminhos e autenticaç🌍

# %%
import sys, os
from pathlib import Path

# Adiciona o diretório src ao path para localizar os módulos
if os.path.exists("src"):
    sys.path.append(os.path.abspath("src"))

is_colab = 'google.colab' in sys.modules
if is_colab:
    print("🌍 Rodando no Google Colab. Autenticando...")
    from google.colab import auth
    auth.authenticate_user()
else:
    print("💻 Rodando em ambiente Local.")

print("✅ Setup concluído!")

# %% [markdown]
# ### 📺 2. Iniciar Dashboard
# Clique no botão **Sincronizar Hub** na barra lateral para carregar os dados do GCS.

# %%
from ipam_gif_factory.interfaces.colab_dashboard import start_dashboard

# Inicializa a interface
dash = start_dashboard()
